# %%
import os

os.getcwd()

# %%
import pandas as pd

excel_filename = 'field_2024/Official_Fieldbook_23_24_Full_incomplete.xlsx'

data_xlsx = pd.read_excel(excel_filename)

# %%
data_xlsx.head(10)
# Out:
#    year    location study         line_id  plot_num  line_num  range_field  \
# 0  2024  beltsville   wvt             516        28        28            1
# 1  2024  beltsville   wvt            3329       128       128            2
# 2  2024  beltsville   wvt       EPIX 3498        49        49            3
# 3  2024  beltsville   wvt       EPIX 3489        48        48            4
# 4  2024  beltsville   wvt  7-MD131/JAGGER       101       101            5
# 5  2024  beltsville   wvt         MBX 127        19        19            6
# 6  2024  beltsville   wvt         MBX 223        22        22            7
# 7  2024  beltsville   wvt     19MD_1-9-37       108       108            8
# 8  2024  beltsville   wvt        MAS #155        52        52            9
# 9  2024  beltsville   wvt  FHB-MAS02-09-3        93        93           10
#
#    row_field  range_study  row_study  ...  height  awn  fhb  pm  glume_blotch  \
# ...

# %%
from openpyxl import load_workbook 

wb = load_workbook(excel_filename)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       1 from openpyxl import load_workbook
#       3 wb = load_workbook(excel_filename)
# ----> 5 print(wb.sheet_names)
#
# AttributeError: 'Workbook' object has no attribute 'sheet_names'

# %%
for sheet in wb.sheetnames:
    print(sheet)
    df = pd.read_excel(excel_filename, sheet_name=sheet)
    df.to_csv(f"{sheet}.csv")
# Out:
# BV WVT
# BV PNR
# BV BVT
# BV AYT+1
# BV AYT+2
# BV PYT1
# BV PYT2
# BV PYT3
# BV AYT
# BV Trit_200
# BV Trit_21
# BV Headrows Wheat
# BV Headrows Trit NEED SYDNEY
# CV WVT
# CV GAWN
# CV EUN
# CV PNR
# CV BVT
# CV BPYT
# CV AYT+1
# CV AYT+2
# CV AYT
# CV PYT1
# CV PYT2
# CV PYT3
# CV DH
# CV Trit_21
# CV Trit_36
# CV Trit_200
# CV DH Headrows MISSING DH3
# CV F5 Headrows NEED TO FINISH
# Wye WVT
# Wye MAS
# Wye Leading Edge
# Wye MsDx
# Wye UBW
# Wye SUN
# Wye PNR
# Wye AYT+1
# Wye AYT+2
# Wye AYT
# Wye BVT
